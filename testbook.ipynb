# %%
# Monday 09/19/2022 

height = int(input('Height of Pyramid: '))

while height < 1 or height > 8:
    height = int(input('Height of Pyramid: '))

for i in range(height):
    for j in range(height - i+1):
        print(' ', end="")
    for k in range(i+1):
        print('#', end="")
    print('')

# %%
import numpy
numpy.__version__

# %%
# Tuesday 09/20/2022 - Saturday 9/24/2022

key = input('Key:')

def keyList(key):
    return list(key)
    # generates list that's the entire key under list "key"

while len(key) != 26:
    print('Key must contain 26 characters.')
    key = input('Key')
    # checks for 26 characters in list "key"

plaintext = input('Plaintext:')

def plaintextList(plaintext):
    return list(plaintext)
    # generates similar list thats plain text in characters under plaintext


# the above is fine. 

def getEncodedList():
    
    asciiNum = []
        # asciinumber is the number that corresponds with the plainText numbers(0 is q, etc)
    
    for i in range(0,len(plaintext)):
        
        if ord(plaintext[i]) ==  32:
            asciiNum.append(-1)
        elif ord(plaintext[i]) < 97:
            asciiNum.append(ord(plaintext[i])-65)
            # so capital letters dont break it
        else:
            asciiNum.append(ord(plaintext[i])-97)
        # adds the letter as its number if it's not a space; if it is, it assigns it as -1
       
    letter = []
    
    for j in range (0,len(asciiNum)):

        if asciiNum[j] != -1:
            letter.append(key[asciiNum[j]])
        else:
            letter.append(" ")

        print (letter[j], end ="")
    # prints and encodes

    # internally screaming rn (and now i have this song associated with the off center endpin dot on my own violin)



getEncodedList()

# final thoughts - no, i didnt need a dictionary in the end and that was overcomplicating things.
# chr only undid whatever i did so haha to that

# %%
# reverse key generator
# Monday 09/26/2022 during study hall as an experimental project
ogKey = input('Original Key: ')

def ogKeyList():
    return list(ogKey)

while len(ogKey) != 26:
    print("Key must be 26 characters long.")
    ogKey = input('Original Key: ')

def getReverseKey():

    orderNumber = []
    for i in range(0,len(ogKey)):
        
        orderNumber.append(ord(ogKey[i])-97)

        # takes the ascii number and turns it into the number that it is in the alphabet
        # takes the keylist by taking that order number

    decoderKeyList = []
    for j in range(0, len(orderNumber)):
    
        decoderKeyList.append(ogKey[orderNumber[j]])
        # take the number, and make a list that takes the old key and takes whatever
        # letter is in that number's place and puts it in the position that q was in 1st list
        print(decoderKeyList[j], end="")
    
    # this is very broken right now but it should work. issue is with for loop #2 since testing just 1 works just fine 
    # it works but the key doesn't :')




getReverseKey()

# %%
import pyautogui
import time

def tabrefresh(index):   
    pyautogui.hotkey('command', 't') # open new tab when discord stops this from working
    pyautogui.hotkey('command', '1') # how to implement in below?
    pyautogui.hotkey('command', 'w')

    time.sleep(1)

    pyautogui.typewrite("https://discord.com/channels/@me \n", 0)
    time.sleep(5)
    #pyautogui.click(778, 160, 1, 0, button='left') # clicks Add Friend
    #time.sleep(1)

time.sleep(3)
# pyautogui.click(778, 160, 1, 0, button='left') # clicks Add Friend
# switch to discord.com/channels/@me at that point under All(no DM open)

# the above is extraneous because you have no friends

for i in range (2361,6767):
    if (len(str(i)) == 1):    
       if ((i-1)%3 != 0):
            pyautogui.click(500, 300, 3, 0.2, button='left')
            pyautogui.hotkey('command', 'a')
            pyautogui.typewrite(['backspace'], 0)
            pyautogui.typewrite("ParalelUs#000" + str(i) + "\n", 0)
            time.sleep(2)

       else:
            tabrefresh(i)

            pyautogui.click(500, 300, 3, 0.2, button='left')
            pyautogui.hotkey('command', 'a')
            pyautogui.typewrite(['backspace'], 0)

            pyautogui.typewrite("ParalelUs#000" + str(i) + "\n", 0)
            time.sleep(2)

    elif (len(str(i)) == 2):
        if ((i-1)%3 != 0):
            pyautogui.click(500, 300, 3, 0.2, button='left')
            pyautogui.hotkey('command', 'a')
            pyautogui.typewrite(['backspace'], 0)
            pyautogui.typewrite("ParalelUs#00" + str(i) + "\n", 0)
            time.sleep(2)
        else:
            tabrefresh(i)

            pyautogui.click(500, 300, 3, 0.2, button='left')
            pyautogui.hotkey('command', 'a')
            pyautogui.typewrite(['backspace'], 0)
            pyautogui.typewrite("ParalelUs#00" + str(i) + "\n", 0)
            time.sleep(2)
    elif (len(str(i)) == 3):
        if ((i-1)%3 != 0):
            pyautogui.click(500, 300, 3, 0.2, button='left')
            pyautogui.hotkey('command', 'a')
            pyautogui.typewrite(['backspace'], 0)
            pyautogui.typewrite("ParalelUs#0" + str(i) + "\n", 0)
            time.sleep(2.5)
        else:
            tabrefresh(i)
            
            pyautogui.click(500, 300, 3, 0.2, button='left')
            pyautogui.hotkey('command', 'a')
            pyautogui.typewrite(['backspace'], 0)
            pyautogui.typewrite("ParalelUs#0" + str(i) + "\n", 0)
            time.sleep(2.5)
    elif (len(str(i)) == 4):
        if ((i-1)%3 != 0):
            pyautogui.click(500, 300, 3, 0.2, button='left')
            pyautogui.hotkey('command', 'a')
            pyautogui.typewrite(['backspace'], 0)
            pyautogui.typewrite("ParalelUs#" + str(i) + "\n", 0)
            time.sleep(2.5)
        else:
            tabrefresh(i)

            pyautogui.click(500, 300, 3, 0.2, button='left')
            pyautogui.hotkey('command', 'a')
            pyautogui.typewrite(['backspace'], 0)
            pyautogui.typewrite("ParalelUs#" + str(i) + "\n", 0)
            time.sleep(2.5)

# %%
import pyautogui
import time

username = 'ParalelUs'

def tabrefresh():   
    pyautogui.hotkey('command', 't') # open new tab when discord stops this from working
    pyautogui.hotkey('command', '1') # how to implement in below?
    pyautogui.hotkey('command', 'w')

    time.sleep(1)

    pyautogui.typewrite("https://discord.com/channels/@me \n")
    time.sleep(5)
    pyautogui.click(778, 160, 1, 0, button='left') # clicks Add Friend
    #time.sleep(1)

def log():
    pyautogui.hotkey('command', 'a')
    pyautogui.hotkey('command', 'c')
    pyautogui.hotkey('command', 'tab')

    pyautogui.hotkey('command', 'v')
    pyautogui.typewrite('\n')
    pyautogui.hotkey('command','tab')

    pyautogui.click(500, 300, 1, 0, button='left')
    pyautogui.typewrite('\n')

def clear():
    pyautogui.click(500, 300, 3, 0.2, button='left')
    pyautogui.hotkey('command', 'a')
    pyautogui.typewrite(['backspace'])

time.sleep(3)
pyautogui.click(778, 160, 1, 0, button='left') # clicks Add Friend
# switch to discord.com/channels/@me at that point under All(no DM open)

# the above is extraneous if you have no friends

for i in range (4041,6767):
    if (len(str(i)) == 1):    
       if ((i-1)%3 != 0):
            clear()
            pyautogui.typewrite(username + "#000" + str(i)) 

            log()
            time.sleep(2.5)

       else:
            tabrefresh()

            clear()

            pyautogui.typewrite(username + "#000" + str(i))

            log()
            time.sleep(2.5)

    elif (len(str(i)) == 2):
        if ((i-1)%3 != 0):
            clear()

            pyautogui.typewrite(username + "#00" + str(i))
            
            log()
            time.sleep(2.5)
        else:
            tabrefresh()

            clear()

            pyautogui.typewrite(username + "#00" + str(i))

            log()
            time.sleep(2.5)
    elif (len(str(i)) == 3):
        if ((i-1)%3 != 0):
            clear()

            pyautogui.typewrite(username + "#0" + str(i))

            log()
            time.sleep(2.5)
        else:
            tabrefresh()
            
            clear()

            pyautogui.typewrite(username+ "#0" + str(i))

            log()
            time.sleep(2.5)
    elif (len(str(i)) == 4):
        if ((i-1)%3 != 0):
            clear()

            pyautogui.typewrite(username + "#" + str(i))

            log()
            time.sleep(2.5)
        else:
            tabrefresh()

            clear()

            pyautogui.typewrite(username + "#" + str(i))

            log()
            time.sleep(2.5)

# %%
import pyautogui
import time

def tabrefresh(index):   
    pyautogui.hotkey('command', 't') # open new tab when discord stops this from working
    pyautogui.hotkey('command', '1') # how to implement in below?
    pyautogui.hotkey('command', 'w')

    time.sleep(1)

    pyautogui.typewrite("https://discord.com/channels/@me \n", 0)
    time.sleep(7)
    pyautogui.click(778, 160, 1, 0, button='left') # clicks Add Friend
    time.sleep(1)

time.sleep(3)

for i in range (1,7):
    if ((i-1)%3 != 0):
        pyautogui.click(500, 300, 3, 0.2, button='left')
        pyautogui.hotkey('command', 'a')
        pyautogui.typewrite(['backspace'], 0)
        pyautogui.typewrite("Someone_#0" + str(759) + "\n", 0)
        time.sleep(2)
        print("Completed task number " + str(i))
    else:
        tabrefresh(i)
        
        pyautogui.click(500, 300, 3, 0.2, button='left')
        pyautogui.hotkey('command', 'a')
        pyautogui.typewrite(['backspace'], 0)
        pyautogui.typewrite("Someone_#0" + str(759) + "\n", 0)
        time.sleep(2)
        print("Completed task number " + str(i))

# %%
import pyautogui
import time

time.sleep(4)

# Whatsapp
pyautogui.click(778,790,1,0, button="left")
pyautogui.typewrite("Happy New Year to EST! (sent with pyautogui as will the following) \n", 0)

# iMesssage, start in 3rd floor
pyautogui.hotkey('command','tab')
pyautogui.typewrite("Happy New Year! \n", 0)
pyautogui.hotkey('command','5') # the next big gc
pyautogui.typewrite("Happy New Year! \n", 0)
pyautogui.hotkey('command','7') # some adhd individuals
pyautogui.typewrite("Happy New Year! \n", 0)

#Discord 
pyautogui.keyDown('command')
pyautogui.typewrite(['tab'])
pyautogui.typewrite(['tab'])
pyautogui.keyUp('command')
pyautogui.typewrite("@everyone Happy New Year! \n", 0) 

#WhatsApp 
time.sleep(3600)

pyautogui.keyDown('command')
pyautogui.typewrite(['tab'])
pyautogui.typewrite(['tab'])
pyautogui.keyUp('command')
pyautogui.click(778,790,1,0, button="left")
pyautogui.typewrite("Happy New Year to CST!  \n", 0)

time.sleep(3600)

pyautogui.click(778,790,1,0, button="left")
pyautogui.typewrite("Happy New Year to MST! \n", 0)

time.sleep(3600)

pyautogui.click(778,790,1,0, button="left")
pyautogui.typewrite("Happy New Year to PST! \n", 0)

time.sleep(3600)

pyautogui.click(778,790,1,0, button="left")
pyautogui.typewrite("Happy New Year to AKST! \n", 0)

time.sleep(3600)

pyautogui.click(778,790,1,0, button="left")
pyautogui.typewrite("Happy New Year to HST! \n", 0)

# %%
import pyautogui
import time

time.sleep(5)

for i in range (1,999):
    pyautogui.click(417,550,1,0.25, button = 'left')
    # pyautogui.click(725,350,1,0.75, button = 'left')

    # pyautogui.click(417,350,1,5, button = 'left')
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 time.sleep(5)
#       6 for i in range (1,999):
# ----> 7     pyautogui.click(417,550,1,0.25, button = 'left')
#       8     # pyautogui.click(725,350,1,0.75, button = 'left')
#       9
#      10     # pyautogui.click(417,350,1,5, button = 'left')
#
# File ~/Documents/GitHub/macrosbutpython/pyautogui/__init__.py:597, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     595 @functools.wraps(wrappedFunction)
#     596 def wrapper(*args, **kwargs):
# --> 597     failSafeCheck()
#     598     returnVal = wrappedFunction(*args, **kwargs)
#     599     _handlePause(kwargs.get("_pause", True))
#
# File ~/Documents/GitHub/macrosbutpython/pyautogui/__init__.py:1722, in failSafeCheck()
#    1720 def failSafeCheck():
#    1721     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# ...

# %%
import pyautogui
import time


for i in range (0,8):
    pyautogui.click(770,780,1,0,button = 'left')
    if (i==0):
        pyautogui.typewrite("Happy Birthday @Pando#0346 ! \n")
    pyautogui.typewrite("Congratulations, you have been an adult for " + str(i) + " hours @Pando#0346 ! \n")
    time.sleep(3600)
